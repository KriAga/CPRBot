# %%
import pandas as pd

# %%
data = pd.read_csv("D:\Miscellaneous\Work\F\CPRBot\TradingView_Alerts_Log_2020-08-08.csv")

# %%
data["Time"] = pd.to_datetime(data["Time"], infer_datetime_format=True)

# %%
data
# Out:
#      Alert ID             Ticker  \
# 0    88716582  NSE:BANKNIFTY, 1m
# 1    88716582  NSE:BANKNIFTY, 1m
# 2    88716582  NSE:BANKNIFTY, 1m
# 3    88716582  NSE:BANKNIFTY, 1m
# 4    88716582  NSE:BANKNIFTY, 1m
# ..        ...                ...
# 350  88718783  NSE:BANKNIFTY, 1m
# 351  88721944  NSE:BANKNIFTY, 1m
# 352  88718783  NSE:BANKNIFTY, 1m
# 353  88721944  NSE:BANKNIFTY, 1m
# 354  88718689  NSE:BANKNIFTY, 1m
#
#                                            Description  \
# 0    BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDH...
# 1    BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDH...
# 2    BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDH...
# 3    BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDH...
# 4    BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDH...
# ..                                                 ...
# 350  BANKNIFTY, 1 Crossing Down CPR BY KGS TRICKS P...
# 351  BANKNIFTY, 1 Crossing Up CPR BY KGS TRICKS PDL...
# 352  BANKNIFTY, 1 Crossing Down CPR BY KGS TRICKS P...
# ...

# %%
buy_indicator_R1 = False
buy_indicator_PDH = False
sell_indicator_S1 = False
sell_indicator_PDL = False

buy_indicator = False
sell_indicator = False

buy_indicator_S2 = False
sell_indicator_R2 = False

# %%
def crossing_up_R1(value):
    global buy_indicator, buy_indicator_PDH, buy_indicator_R1
    buy_indicator_R1 = True
    data = value
    if buy_indicator_PDH:
        buy_indicator = True
    if buy_indicator:
        print("BUY", data)
    # print('crossing_up_R1', buy_indicator, buy_indicator_PDH, buy_indicator_R1)
    return ('crossing_up_R1')

def crossing_down_R1(value):
    global buy_indicator, buy_indicator_R1
    buy_indicator_R1 = False
    buy_indicator = False
    # print('crossing_down_R1')
    return ('crossing_down_R1')

def crossing_up_PDH(value):
    global buy_indicator, buy_indicator_R1, buy_indicator_PDH
    buy_indicator_PDH = True
    data = value
    if buy_indicator_R1:
        buy_indicator = True
    if buy_indicator:
        print("Buy", data)
    # print('crossing_up_PDH', buy_indicator, buy_indicator_R1)
    return ('crossing_up_PDH')

def crossing_down_PDH(value):
    global buy_indicator, buy_indicator_PDH
    buy_indicator_PDH = False
    buy_indicator = False
    # print('crossing_down_PDH')
    return ('crossing_down_PDH')

def crossing_up_S1(value):
    global sell_indicator, sell_indicator_S1
    sell_indicator_S1 = False
    sell_indicator = False
    # print('crossing_up_S1')
    return ('crossing_up_S1')

def crossing_down_S1(value):
    global sell_indicator, sell_indicator_PDL, sell_indicator_S1
    sell_indicator_S1 = True
    data = value
    if sell_indicator_PDL:
        sell_indicator = True
    if sell_indicator:
        print("Sell:", data)
    # print('crossing_down_S1')
    return ('crossing_down_S1')

def crossing_up_PDL(value):
    global sell_indicator, sell_indicator_PDL
    sell_indicator_PDL = False
    sell_indicator = False
    # print('crossing_up_PDL')
    return ('crossing_up_PDL')

def crossing_down_PDL(value):
    global sell_indicator, sell_indicator_S1, sell_indicator_PDL
    sell_indicator_PDL = True
    data = value
    if sell_indicator_S1:
        sell_indicator = True
    if sell_indicator:
        print("Sell:", data)
    # print('crossing_down_PDL')
    return ('crossing_down_PDL')

def crossing_down_S2(value):
    global buy_indicator, buy_indicator_S2
    buy_indicator_S2 = True
    data = value
    buy_indicator = True
    if buy_indicator:
        print("Buy", data)
    # print('crossing_down_S2')
    return ('crossing_down_S2')

def crossing_up_R2(value):
    global sell_indicator, sell_indicator_R2
    sell_indicator_R2 = True
    sell_indicator = True
    data = value
    if sell_indicator:
        print("Sell", data)
    # print('crossing_up_R2')
    return ('crossing_up_R2')

# %%
date = datetime.now()
for index, alerts in data.iterrows():
    # print(alerts["Description"])
    if date == alerts["Time"]:
        date = alerts["Time"]
        pass
    elif "Crossing Up CPR BY KGS TRICKS PDH Buy:" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_up_PDH(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Down CPR BY KGS TRICKS R1" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_down_R1(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Up CPR BY KGS TRICKS R1" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_up_R1(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Up CPR BY KGS TRICKS R2 Sell" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_up_R2(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Up CPR BY KGS TRICKS PDL" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_up_PDL(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Down CPR BY KGS TRICKS PDL" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_down_PDL(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Down CPR BY KGS TRICKS S1" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_down_S1(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Up CPR BY KGS TRICKS S1" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_up_S1(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Down CPR BY KGS TRICKS PDH" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_down_PDH(float(alerts["Description"].split(' ')[-1].strip()))
    elif "Crossing Down CPR BY KGS TRICKS S2" in alerts["Description"]:
        print(alerts["Time"])
        # print(float(alerts["Description"].split(' ')[-1].strip()))
        crossing_down_S2(float(alerts["Description"].split(' ')[-1].strip()))
# Out:
# 2020-08-05 08:57:49+00:00
# 2020-08-05 08:45:00+00:00
# 2020-08-05 08:44:57+00:00
# 2020-08-05 08:43:37+00:00
# 2020-08-05 08:42:21+00:00
# 2020-08-05 08:41:02+00:00
# 2020-08-05 08:35:15+00:00
# 2020-08-05 08:31:41+00:00
# 2020-08-05 08:30:06+00:00
# 2020-08-05 08:18:26+00:00
# 2020-08-05 08:12:01+00:00
# 2020-08-05 08:11:55+00:00
# 2020-08-05 08:10:20+00:00
# 2020-08-05 08:09:32+00:00
# 2020-08-05 08:04:22+00:00
# 2020-08-05 08:03:08+00:00
# 2020-08-05 08:02:13+00:00
# 2020-08-05 07:44:26+00:00
# 2020-08-05 07:36:03+00:00
# 2020-08-05 07:36:01+00:00
# BUY 21690.6
# 2020-08-05 07:35:37+00:00
# 2020-08-05 07:35:15+00:00
# BUY 21691.4
# 2020-08-05 07:34:08+00:00
# 2020-08-05 07:34:06+00:00
# BUY 21690.3
# 2020-08-05 07:33:48+00:00
# 2020-08-05 07:33:45+00:00
# BUY 21694.7
# 2020-08-05 07:12:01+00:00
# BUY 21692.0
# 2020-08-05 07:12:00+00:00
# 2020-08-05 07:11:54+00:00
# BUY 21693.0
# 2020-08-05 06:54:48+00:00
# Buy 21576.75
# 2020-08-05 06:38:24+00:00
# Buy 21580.35
# ...
